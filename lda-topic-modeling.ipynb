# %%
# imports 
import pandas as pd 
import json 
import glob
import numpy as np
#gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

#nltk
from nltk.corpus import stopwords

#visualization
import pyLDAvis
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()

# %%
stopwords = stopwords.words('english')

# %%
data = pd.read_csv('data/preprocessed-reviews.csv')

# %%
def lemmatization(texts, allowed_posttags=['NOUN','ADJ','VERB','ADV']):
    nlp =

# %%
spacy.load('en_core_web_sm', disable=['parser','ner'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 spacy.load('en_core_web_sm', disable=['parser','ner'])
#
# NameError: name 'spacy' is not defined

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\Kevin\anaconda3\envs\learn-env:
# #
# # Name                    Version                   Build  Channel
# _py-xgboost-mutex         2.0                       cpu_0    conda-forge
# abseil-cpp                20200225.2           ha925a31_2    conda-forge
# absl-py                   0.10.0                   pypi_0    pypi
# aiohttp                   3.6.3            py38h1e8a9f7_2    conda-forge
# appdirs                   1.4.4                    pypi_0    pypi
# argon2-cffi               20.1.0           py38h294d835_2    conda-forge
# arrow-cpp                 0.15.1           py38h47fa567_6
# arviz                     0.10.0                     py_0    conda-forge
# astunparse                1.6.3                    pypi_0    pypi
# async-timeout             3.0.1                   py_1000    conda-forge
# async_generator           1.10                       py_0    conda-forge
# attrs                     20.2.0             pyh9f0ad1d_0    conda-forge
# aws-c-common              0.4.59               h8ffe710_1    conda-forge
# aws-c-event-stream        0.1.6                h9490e6b_5    conda-forge
# aws-checksums             0.1.9                h25771f4_2    conda-forge
# aws-sdk-cpp               1.8.70               he2782d2_1    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                pyhd8ed1ab_3    conda-forge
# backports.functools_lru_cache 1.6.1                      py_0    conda-forge
# beautifulsoup4            4.12.2                   pypi_0    pypi
# blas                      1.0                         mkl
# bleach                    3.2.1              pyh9f0ad1d_0    conda-forge
# bokeh                     3.1.1                    pypi_0    pypi
# boost-cpp                 1.67.0               hea38baa_0    conda-forge
# boto                      2.49.0                     py_0    conda-forge
# boto3                     1.15.16            pyh9f0ad1d_0    conda-forge
# botocore                  1.18.16            pyh9f0ad1d_0    conda-forge
# branca                    0.4.1                      py_0    conda-forge
# brotli                    1.0.9                h8ffe710_6    conda-forge
# brotli-bin                1.0.9                h8ffe710_6    conda-forge
# brotlipy                  0.7.0           py38h294d835_1003    conda-forge
# bz2file                   0.98                       py_0    conda-forge
# bzip2                     1.0.8                h8ffe710_4    conda-forge
# c-ares                    1.16.1               he774522_3    conda-forge
# ca-certificates           2022.12.7            h5b45459_0    conda-forge
# cachetools                4.1.1                      py_0    conda-forge
# certifi                   2022.12.7          pyhd8ed1ab_0    conda-forge
# cffi                      1.14.3           py38h0e640b1_1    conda-forge
# cftime                    1.2.1            py38h1e00858_1    conda-forge
# chardet                   3.0.4           py38h9bdc248_1008    conda-forge
# charset-normalizer        3.1.0                    pypi_0    pypi
# clang                     11.0.0               h57928b3_2    conda-forge
# clang-11                  11.0.0          default_h5c34c98_2    conda-forge
# clangxx                   11.0.0          default_h5c34c98_2    conda-forge
# click                     7.1.2              pyh9f0ad1d_0    conda-forge
# colorama                  0.4.3                      py_0    conda-forge
# compiler-rt               11.0.0               h2e52968_2    conda-forge
# compiler-rt_win-64        11.0.0               h587dcfd_2    conda-forge
# contourpy                 1.0.7                    pypi_0    pypi
# convertdate               2.2.2              pyh9f0ad1d_0    conda-forge
# cryptography              3.1.1            py38h0e640b1_1    conda-forge
# curl                      7.71.1               h86230a5_2
# cvxpy                     1.1.6            py38h7ae7562_0    conda-forge
# cvxpy-base                1.1.6            py38h251f6bf_0    conda-forge
# cycler                    0.10.0                     py_2    conda-forge
# cython                    0.29.21          py38h885f38d_2    conda-forge
# decorator                 4.4.2                      py_0    conda-forge
# defusedxml                0.6.0                      py_0    conda-forge
# docutils                  0.15.2           py38haa244fe_6    conda-forge
# double-conversion         3.1.5                h0e60522_2    conda-forge
# ecos                      2.0.7.post1      py38h347fdf6_4    conda-forge
# entrypoints               0.3             pyhd8ed1ab_1003    conda-forge
# ephem                     3.7.7.1          py38h1e8a9f7_1    conda-forge
# et_xmlfile                1.0.1                   py_1001    conda-forge
# fbprophet                 0.7.1            py38h7ae7562_0    conda-forge
# folium                    0.11.0                     py_0    conda-forge
# fonttools                 4.40.0                   pypi_0    pypi
# freetype                  2.10.3               hd328e21_0    conda-forge
# frozendict                2.3.8                    pypi_0    pypi
# future                    0.18.2             pyhd8ed1ab_6    conda-forge
# gast                      0.3.3                    pypi_0    pypi
# gensim                    3.8.3            py38h885f38d_4    conda-forge
# gflags                    2.2.2             ha925a31_1004    conda-forge
# glog                      0.4.0                h0174b99_3    conda-forge
# google-api-core           1.22.2           py38h21ff451_0
# google-auth               1.22.0                     py_0    conda-forge
# google-auth-oauthlib      0.4.1                    pypi_0    pypi
# google-cloud-core         1.4.3              pyh9f0ad1d_0    conda-forge
# google-cloud-storage      1.31.2             pyh9f0ad1d_0    conda-forge
# google-crc32c             1.0.0            py38h0523e21_1    conda-forge
# google-pasta              0.2.0                    pypi_0    pypi
# google-resumable-media    1.1.0              pyh9f0ad1d_0    conda-forge
# googleapis-common-protos  1.52.0           py38h5b57dd5_1    conda-forge
# grpc-cpp                  1.26.0               h9f84659_0    conda-forge
# grpcio                    1.31.0           py38h735fc1f_0    conda-forge
# h5py                      2.10.0                   pypi_0    pypi
# hdf4                      4.2.13            h0e5069d_1005    conda-forge
# hdf5                      1.10.6          nompi_h5268f04_1112    conda-forge
# holidays                  0.10.3             pyh9f0ad1d_0    conda-forge
# html5lib                  1.1                      pypi_0    pypi
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha925a31_3
# idna                      2.10               pyh9f0ad1d_0    conda-forge
# imbalanced-learn          0.7.0                      py_1    conda-forge
# importlib-metadata        2.0.0                      py_1    conda-forge
# importlib-resources       5.12.0                   pypi_0    pypi
# importlib_metadata        2.0.0                         1    conda-forge
# intel-openmp              2019.4                      245
# ipykernel                 5.3.4            py38h7b7c402_1    conda-forge
# ipython                   7.18.1           py38h1cdfbd6_1    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                7.5.1              pyh9f0ad1d_1    conda-forge
# jdcal                     1.4.1                      py_0    conda-forge
# jedi                      0.17.2           py38haa244fe_2    conda-forge
# jinja2                    2.11.2             pyh9f0ad1d_0    conda-forge
# jmespath                  0.10.0             pyh9f0ad1d_0    conda-forge
# joblib                    0.17.0                     py_0    conda-forge
# jpeg                      9d                   h8ffe710_0    conda-forge
# jsonschema                3.2.0              pyhd8ed1ab_3    conda-forge
# jupyter                   1.0.0            py38haa244fe_8    conda-forge
# jupyter_client            6.1.7                      py_0    conda-forge
# jupyter_console           6.2.0                      py_0    conda-forge
# jupyter_contrib_core      0.3.3                      py_2    conda-forge
# jupyter_contrib_nbextensions 0.7.0              pyhd8ed1ab_0    conda-forge
# jupyter_core              4.6.3            py38haa244fe_2    conda-forge
# jupyter_highlight_selected_word 0.2.0           py38haa244fe_1005    conda-forge
# jupyter_latex_envs        1.4.6           pyhd8ed1ab_1002    conda-forge
# jupyter_nbextensions_configurator 0.6.1              pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.1.2              pyh9f0ad1d_0    conda-forge
# kaggle                    1.5.13                   pypi_0    pypi
# keras                     2.4.3                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# kiwisolver                1.2.0            py38h95a2b95_1    conda-forge
# korean_lunar_calendar     0.2.1              pyh9f0ad1d_0    conda-forge
# krb5                      1.18.2               hc04afaa_0
# lcms2                     2.11                 h6a326e1_1    conda-forge
# libblas                   3.8.0                    14_mkl    conda-forge
# libboost                  1.67.0               hd9e427e_4
# libbrotlicommon           1.0.9                h8ffe710_6    conda-forge
# libbrotlidec              1.0.9                h8ffe710_6    conda-forge
# libbrotlienc              1.0.9                h8ffe710_6    conda-forge
# libcblas                  3.8.0                    14_mkl    conda-forge
# libcrc32c                 1.1.1                h0e60522_2    conda-forge
# libcurl                   7.71.1               h86230a5_2
# libiconv                  1.16                 he774522_0    conda-forge
# liblapack                 3.8.0                    14_mkl    conda-forge
# libnetcdf                 4.7.4           nompi_h3a9aa94_107    conda-forge
# libpng                    1.6.37               h1d00b33_2    conda-forge
# libprotobuf               3.11.2               h1a1b453_0    conda-forge
# libpython                 2.0              py38haa244fe_1    conda-forge
# libsodium                 1.0.18               h8d14728_1    conda-forge
# libssh2                   1.9.0                hb06d900_5    conda-forge
# libtiff                   4.1.0                h56a325e_0
# libxml2                   2.9.10               hf5bbc77_4    conda-forge
# libxslt                   1.1.33               h65864e5_2    conda-forge
# libzlib                   1.2.11            h8ffe710_1013    conda-forge
# lunarcalendar             0.0.9                      py_0    conda-forge
# lxml                      4.9.2                    pypi_0    pypi
# lz4                       3.1.3            py38h2bbff1b_0
# lz4-c                     1.8.1.2              h2fa13f4_0
# m2w64-binutils            2.25.1                        5    conda-forge
# m2w64-bzip2               1.0.6                         6    conda-forge
# m2w64-crt-git             5.0.0.4636.2595836               2    conda-forge
# m2w64-gcc                 5.3.0                         6    conda-forge
# m2w64-gcc-ada             5.3.0                         6    conda-forge
# m2w64-gcc-fortran         5.3.0                         6    conda-forge
# m2w64-gcc-libgfortran     5.3.0                         6    conda-forge
# m2w64-gcc-libs            5.3.0                         7    conda-forge
# m2w64-gcc-libs-core       5.3.0                         7    conda-forge
# m2w64-gcc-objc            5.3.0                         6    conda-forge
# m2w64-gmp                 6.1.0                         2    conda-forge
# m2w64-headers-git         5.0.0.4636.c0ad18a               2    conda-forge
# m2w64-isl                 0.16.1                        2    conda-forge
# m2w64-libiconv            1.14                          6    conda-forge
# m2w64-libmangle-git       5.0.0.4509.2e5a9a2               2    conda-forge
# m2w64-libwinpthread-git   5.0.0.4634.697f757               2    conda-forge
# m2w64-make                4.1.2351.a80a8b8               2    conda-forge
# m2w64-mpc                 1.0.3                         3    conda-forge
# m2w64-mpfr                3.1.4                         4    conda-forge
# m2w64-pkg-config          0.29.1                        2    conda-forge
# m2w64-toolchain           5.3.0                         7    conda-forge
# m2w64-toolchain_win-64    2.4.0                         0    conda-forge
# m2w64-tools-git           5.0.0.4592.90b8472               2    conda-forge
# m2w64-windows-default-manifest 6.4                           3    conda-forge
# m2w64-winpthreads-git     5.0.0.4634.697f757               2    conda-forge
# m2w64-zlib                1.2.8                        10    conda-forge
# markdown                  3.3.2                    pypi_0    pypi
# markupsafe                1.1.1            py38h294d835_3    conda-forge
# matplotlib                3.7.1                    pypi_0    pypi
# mistune                   0.8.4           pyh1a96a4e_1006    conda-forge
# mkl                       2019.4                      245
# mkl-service               2.3.0            py38hfa6e2cd_0    conda-forge
# mkl_fft                   1.2.0            py38h45dec08_0
# mkl_random                1.1.0            py38he350917_0    conda-forge
# msys2-conda-epoch         20160418                      1    conda-forge
# multidict                 4.7.5            py38h294d835_2    conda-forge
# multitasking              0.0.11                   pypi_0    pypi
# nbclient                  0.5.1                      py_0    conda-forge
# nbconvert                 6.0.7            py38haa244fe_3    conda-forge
# nbformat                  5.0.8                      py_0    conda-forge
# nest-asyncio              1.4.1                      py_0    conda-forge
# netcdf4                   1.5.4           nompi_py38h87f19a6_103    conda-forge
# networkx                  2.5.1              pyhd8ed1ab_0    conda-forge
# nltk                      3.5                pyhd8ed1ab_1    conda-forge
# notebook                  6.1.4            py38h32f6830_1    conda-forge
# numpy                     1.24.4                   pypi_0    pypi
# oauthlib                  3.1.0                    pypi_0    pypi
# olefile                   0.46               pyh9f0ad1d_1    conda-forge
# opendatasets              0.1.22                   pypi_0    pypi
# openpyxl                  3.0.5                      py_0    conda-forge
# openssl                   1.1.1l               h8ffe710_0    conda-forge
# opt-einsum                3.3.0                    pypi_0    pypi
# orc                       0.1.0                    pypi_0    pypi
# osqp                      0.6.1            py38he6e81aa_2    conda-forge
# packaging                 23.1                     pypi_0    pypi
# pandas                    2.0.2                    pypi_0    pypi
# pandasql                  0.7.3              pyhd8ed1ab_0    conda-forge
# pandoc                    2.11.4               h8ffe710_0    conda-forge
# pandocfilters             1.4.2                      py_1    conda-forge
# parso                     0.7.0              pyh9f0ad1d_0    conda-forge
# patsy                     0.5.3                    pypi_0    pypi
# pexpect                   4.8.0              pyh1a96a4e_2    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    8.0.0            py38h1d4d63c_0    conda-forge
# pip                       20.2.3                     py_0    conda-forge
# plot-likert               0.4.0                    pypi_0    pypi
# plotly                    4.11.0             pyh9f0ad1d_0    conda-forge
# pmdarima                  2.0.3                    pypi_0    pypi
# probableparsing           0.0.1                    pypi_0    pypi
# prometheus_client         0.8.0              pyh9f0ad1d_0    conda-forge
# prompt-toolkit            3.0.8              pyha770c72_0    conda-forge
# prompt_toolkit            3.0.8                hd8ed1ab_0    conda-forge
# protobuf                  3.11.2           py38he025d50_0    conda-forge
# ptyprocess                0.6.0                   py_1001    conda-forge
# py4j                      0.10.9             pyh9f0ad1d_0    conda-forge
# pyarrow                   0.15.1           py38h47e9c7a_0
# pyasn1                    0.4.8                      py_0    conda-forge
# pyasn1-modules            0.2.7                      py_0    conda-forge
# pybind11                  2.5.0                    pypi_0    pypi
# pycparser                 2.20               pyh9f0ad1d_2    conda-forge
# pygments                  2.7.1                      py_0    conda-forge
# pymeeus                   0.3.7              pyh9f0ad1d_0    conda-forge
# pymongo                   3.11.0           py38h885f38d_4    conda-forge
# pyopenssl                 19.1.0                     py_1    conda-forge
# pyparsing                 2.4.7              pyhd8ed1ab_1    conda-forge
# pyproj                    3.5.0                    pypi_0    pypi
# pyqt                      5.9.2            py38hd77b12b_6
# pyreadline                2.1             py38haa244fe_1007    conda-forge
# pyrsistent                0.17.3           py38h294d835_3    conda-forge
# pysocks                   1.7.1              pyh0701188_6    conda-forge
# pyspark                   3.0.0                      py_0    conda-forge
# pystan                    2.19.1.1         py38h02adce6_3    conda-forge
# python                    3.8.5           h60c2a47_9_cpython    conda-forge
# python-crfsuite           0.9.9                    pypi_0    pypi
# python-dateutil           2.8.2                    pypi_0    pypi
# python-slugify            8.0.1                    pypi_0    pypi
# python_abi                3.8                      3_cp38    conda-forge
# pytz                      2023.3                   pypi_0    pypi
# pywin32                   227              py38h294d835_1    conda-forge
# pywinpty                  0.5.7            py38haa244fe_1    conda-forge
# pyyaml                    5.3.1            py38h294d835_2    conda-forge
# pyzmq                     19.0.2           py38h77b9d75_2    conda-forge
# qt                        5.9.7                hc6833c9_1    conda-forge
# qtconsole                 4.7.7              pyh9f0ad1d_0    conda-forge
# qtpy                      1.9.0                      py_0    conda-forge
# re2                       2019.08.01       vc14h6538335_0    conda-forge
# regex                     2020.10.15       py38h1e8a9f7_0    conda-forge
# requests                  2.31.0                   pypi_0    pypi
# requests-oauthlib         1.3.0                    pypi_0    pypi
# retrying                  1.3.3                      py_2    conda-forge
# rise                      5.7.1            py38haa244fe_2    conda-forge
# rsa                       4.6                pyh9f0ad1d_0    conda-forge
# s3transfer                0.3.3              pyhd8ed1ab_5    conda-forge
# scikit-learn              0.23.2           py38ha09990b_3    conda-forge
# scikit-surprise           1.1.1            py38h6f4d8f0_2    conda-forge
# scipy                     1.5.0            py38h9439919_0
# scs                       2.1.2            py38h7465cd0_2    conda-forge
# seaborn                   0.11.0               h57928b3_1    conda-forge
# seaborn-base              0.11.0             pyhd8ed1ab_1    conda-forge
# send2trash                1.5.0                      py_0    conda-forge
# setuptools                50.3.0           py38haa95532_1
# setuptools-git            1.2                        py_1    conda-forge
# simplegeneric             0.8.1                      py_1    conda-forge
# sip                       4.19.13          py38hd77b12b_0
# six                       1.15.0             pyh9f0ad1d_0    conda-forge
# smart_open                3.0.0              pyh9f0ad1d_0    conda-forge
# snappy                    1.1.8                ha925a31_3    conda-forge
# soupsieve                 2.0.1                      py_1    conda-forge
# sqlalchemy                1.3.19           py38h1e8a9f7_1    conda-forge
# sqlite                    3.33.0               he774522_1    conda-forge
# statsmodels               0.14.0                   pypi_0    pypi
# tensorboard               2.3.0                    pypi_0    pypi
# tensorboard-plugin-wit    1.7.0                    pypi_0    pypi
# tensorflow                2.3.1                    pypi_0    pypi
# tensorflow-estimator      2.3.0                    pypi_0    pypi
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.9.1            py38haa244fe_1    conda-forge
# testpath                  0.4.4                      py_0    conda-forge
# text-unidecode            1.3                      pypi_0    pypi
# threadpoolctl             2.1.0              pyh5ca1d4c_0    conda-forge
# thrift-cpp                0.11.0               h1ebf3fd_3
# tk                        8.6.10               h8ffe710_1    conda-forge
# tornado                   6.0.4            py38h1e8a9f7_2    conda-forge
# tqdm                      4.50.2             pyh9f0ad1d_0    conda-forge
# traitlets                 5.0.5                      py_0    conda-forge
# tzdata                    2023.3                   pypi_0    pypi
# uriparser                 0.9.3                he025d50_1    conda-forge
# urllib3                   1.25.10                    py_0    conda-forge
# usaddress                 0.5.10                   pypi_0    pypi
# vc                        14.1                 h869be7e_1    conda-forge
# vs2015_runtime            14.16.27012          h30e32a0_2    conda-forge
# wcwidth                   0.2.5              pyh9f0ad1d_2    conda-forge
# webencodings              0.5.1                      py_1    conda-forge
# werkzeug                  1.0.1                    pypi_0    pypi
# wheel                     0.35.1             pyh9f0ad1d_0    conda-forge
# widgetsnbextension        3.5.1            py38haa244fe_4    conda-forge
# win_inet_pton             1.1.0              pyhd8ed1ab_6    conda-forge
# wincertstore              0.2             pyhd8ed1ab_1009    conda-forge
# winpty                    0.4.3                         4    conda-forge
# wrapt                     1.12.1                   pypi_0    pypi
# xarray                    0.16.1                     py_0    conda-forge
# xgboost                   1.2.1                    pypi_0    pypi
# xlrd                      1.2.0              pyh9f0ad1d_1    conda-forge
# xyzservices               2023.5.0                 pypi_0    pypi
# xz                        5.2.5                h62dcd97_1    conda-forge
# yaml                      0.2.5                h8ffe710_2    conda-forge
# yarl                      1.5.1            py38he774522_0
# yfinance                  0.2.22                   pypi_0    pypi
# zeromq                    4.3.2                h0e60522_5    conda-forge
# zipp                      3.3.0                      py_0    conda-forge
# zlib                      1.2.11            h8ffe710_1013    conda-forge
# zstd                      1.3.7             haafe652_1001    conda-forge
