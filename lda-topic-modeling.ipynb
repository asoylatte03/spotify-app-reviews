# %%
# imports 
import pandas as pd 
import numpy as np

#gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary

#nltk
from nltk.corpus import stopwords
import itertools

# spacy 
import spacy
#visualization
import pyLDAvis
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()

# %%
# our processed dataset and corpus with all our lemmatized tokens 
spotify_df = pd.read_csv('data/preprocessed-reviews.csv')
corpus = pd.read_csv('data/spotify-reviews.csv')

#our corpus has identical column name, so need to rename
corpus = corpus.rename(columns={'review':'tokens'})
corpus.head()
# Out:
#                                               tokens
# 0  great music service audio high quality app eas...
# 1  please ignore previous negative rating app sup...
# 2  get best spotify experience android annoy plea...
# 3                 really buggy terrible use recently
# 4    dear spotify get song put playlist shuffle play

# %%
# concatenating our two dataframes 
spotify_reviews = pd.concat([spotify_df,corpus], axis=1)

# creating separate dataframes for positive and negative reviews using the sentiment labels 
positive_reviews = spotify_reviews[spotify_reviews.sentiment.str.contains('pos')]
negative_reviews = spotify_reviews[spotify_reviews.sentiment.str.contains('neg')]

# %% [markdown]
# ## Topic Modeling

# %%
stop_words = stopwords.words('english')
stop_words.extend(['app','spotify'])

# for better filtering, adding 'app' and 'spotify' to our stopwords 
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'app', 'spotify']

# %% [markdown]
# ### Topic Modeling Positive Sentiment Reviews

# %%
data = pd.read_csv('data/review-corpus.csv')
# Out:
#                                                   review
# 0      ['great', 'music', 'service', 'audio', 'high',...
# 1      ['please', 'ignore', 'previous', 'negative', '...
# 2      ['get', 'best', 'spotify', 'experience', 'andr...
# 3      ['really', 'buggy', 'terrible', 'use', 'recent...
# 4      ['dear', 'spotify', 'get', 'song', 'put', 'pla...
# ...                                                  ...
# 61589  ['even', 'communicate', 'lyric', 'feature', 'a...
# 61590  ['use', 'sooo', 'good', 'back', 'download', 'f...
# 61591  ['app', 'good', 'take', 'device', 'start', 'co...
# 61592  ['app', 'good', 'hard', 'navigate', 'let', 'pl...
# 61593  ['good', 'sometimes', 'doesnt', 'load', 'music...
#
# [61594 rows x 1 columns]

# %%
token_str = positive_reviews.tokens.values.tolist()
token_str
# Out:
# ['great music service audio high quality app easy use also quick friendly support',
#  'please ignore previous negative rating app super great give',
#  'get best spotify experience android annoy please let get rid',
#  'dear spotify get song put playlist shuffle play',
#  'love selection lyric provide song listening',
#  'still extremely slow change storage external sd card convince do purpose spotify know issue do nothing solve time change sd card faster read write speed samsung brand please add song never appear search playlist',
#  'great app best music app ever use problem play song find songs app wonderful recommend best',
#  'delete app follow reason app fail business model stream service consumer want pay music fully ad successively log single song much close app ad number patient way profit already peak left decline',
#  'amazon premium music family package good everyone listen liked respective alexas room ask play problem spotify premium family alexa integration poor spotify stop play time play different alexa device time ask integration well',
#  'hav music',
#  'improve ia recommend song find similar song best music app youtube good everything else spotify king',
#  'always crash unable play stop work everytime use',
#  'know ad cost free use yes thats right ad straight back back hlaf minute sometimes think little much even volume increase ad',
#  'always favorite platform listen music subscribe alot thing',
#  'voice sweet hearable',
#  'amazing music experience',
#  'everything listen commercial even well even song want know name bring thanks spotify',
#  'jammin hyuh old school hardcore thrash heard year return youth yes please',
#  'best music app ever see',
#  'wow sudden login work even positive correct morning app ask login happen obviously problem find email account tell change password behaviour yeah log spotify xbox suspicious thanks stress morning need renew way teach lesson',
#  'plz remove add ther continuously add list remove add give add',
#  'like song play offline help signal problem',
#  'sometimes try listen playlist play first song try go different go back first little weird',
#  'good app listen music',
#  'deal compare desktop version inferior ability play song bare barely free need say think make point clear enough',
#  'spotify awesome love obscure artist think fingertip well easy access new thing update lose star constantly ask review already do',
#  'best app stream music',
#  'everything go open app last week play bar go open shuts right back',
#  'love app style music selection specific',
#  'pretty good apps well quality music',
#  'love feature app thing bit expensive month subcription',
#  'best birthday present ever receive baby brother listen something least everyday happy selection christian artist music love find new artist let listen great podcasts thank much wonderful app',
#  'downside rotate song month listen great song next month maybe',
#  'sound quality really good listen favourite song anytime anywhere disturbance really good experience love app alot keep provide best service',
#  'keep cut showing song playing',
#  'unuser friendly compare ipad pc',
#  'pay customer nothing say spotify perfecto',
#  'much add get add start song need premium play song',
#  'exceptional application online song love option merge app inter music player samsung overall application work flow less',
#  'spotify good joox fosho',
#  'dose go play like song song even look get star',
#  'great listen favorite artist',
#  'app incredible good use enjoy music everyday minute second love',
#  'app good cool interested app love much iam listen day night spotify full support app suggest try app fun spotify say try spotify try army blink app good army blink today special day army army day love army love blink happy app spotify try spotif love spotify',
#  'love soo much rate star problem constant ad sing option lyric seem appear anymore',
#  'love app small issue find song add like look song take whole different playlist please fix',
#  'really app play song play different',
#  'great song selection amazing audio quality however problem everyday cast google home connection issue lose control volume need open app able change volume inconvenience also think option song rather put playlist single song time consume make playlist easier select multiple album example',
#  'great music quality',
#  'love hear ad satisfy sometimes music play interrupt ad request fix problem enjoy ad peacefully great',
#  'first time user far easy enough navigate',
#  'awesome song find',
#  'work really well android auto long drive home',
#  'please turn shuffle play',
#  'middle song pause restarts whole song go app play song',
#  'love spotify listen music podcasts premium account worth penny',
#  'hell issue patoto man minus random song add even choose song want play view properly play directly start second snippet song even listen music want even playlist play music want big seem google play store issue play fine apple mobile device ipads',
#  'app good fixe sign',
#  'dude app good today use later day check let play playlist random song add toy playlist even select song want play listen short period time say added playlist part say add know want listen full song random bot add random song even interest',
#  'love spotify wish download music',
#  'awesome great music app',
#  'work super well work app doesnt seem want load time ultra laggy lock phone occationally make sense otherwise feature plentiful anything',
#  'even listen favorite song bc shuffle try different account even change even little',
#  'load time wonderful short wait long hear next best thing',
#  'love listening music use cop mechanism love spotify much day spotify load stay spotify logo screen thing try instal uninstalling time restart phone time clear time still open also waited hour load',
#  'use good dont let play playlist pause stop start go back track phone samsung email spotify ask help member nothing work',
#  'app available year amount issue frustrate say stop play randomly background even allow background data use time run background app dissappears toolbar open independently way click playing bottom force close',
#  'really enjoy music life nice app thanks spotify',
#  'cant open app day please fix',
#  'love spotify great family',
#  'app work well try install new version app pioneer car system work spotify anymore mean upgrade apps manually able keep last working version hope spotify fix broken app soon',
#  'use love app soon hat keep play music song playlist like song turn option play similar song playlist end something work recommend',
#  'excellent music experience',
#  'amaze app use time affordable look app lift mood spotify go',
#  'spotify literally account everything come best music experience easy use still many feature honestly realize much need got recommend apple music aesthetically please way well feature get spotify premium even ad still good',
#  'good audio play experience spotify',
#  'best music app till',
#  'use last year straight always use premium essential',
#  'like able save queue playlist like able scroll back queue arbitrary number title playlist play able add song queue rearrange playlist sequence save change playlist prompt end playlist',
#  'best song app',
#  'love app ad level reason choose favorite artist enjoy different playlist mb resso use mb prefer spotify',
#  'nice music quality',
#  'umm lately auto pause problem screen lock hope fix soon',
#  'amazing song artists great app review',
#  'bad good want listen song suddenly play different song try add fav song playlist play song add playlist well okay',
#  'absolutely love spotify obsess music rat start reasom ok basically spotify weird thing song playlist literally nothing play idea fix whats work device spotify account phone phone idk thing randomly kick app sometimes well thats',
#  'really love favorite thing app lyric amaze love singing favorite song',
#  'best music app best collection wil create playlist specially youu love best app ever',
#  'nice app love spotify',
#  'easy play singer song want',
#  'amaze app option download song completely fantasy',
#  'best music app spotify include dolby atmos spatial audio',
#  'speechless app amaze',
#  'cant open app try delete restart phone someone help',
#  'use app year love much',
#  'nice thanks help support',
#  'best music app time amazing give',
#  'please help fix open app logo stuck screen try restart reinstall app work fix',
#  'live remotely spotify way go love',
#  'best app ever use listen music numerous option playlist specially really know well create playlist favourite song appreciate artist mix genre mix mood mix good use spotify wish advantage use free account example skip song',
#  'probably best app find play store love feature app opinion add calller tone ringtone option spotify spotify song apps add feature pay listener amaze',
#  'lot ad come song add come please remove add',
#  'love add play song tv show picture artist profile picture background like solid color album cover corner well find way love mac demarco jumpscared see face nowhere need option take ruin aesthetic',
#  'find song love sometimes find old song love none less',
#  'great music app favorite know thing limited amount skip eatch hour recommend get app great listen song friend love make playlist song',
#  'love sadly buy subscription fully enjoy service love blend mix song tell sound better buy subscription still',
#  'good application search peace listening song find think need improvement shuffle playlist change many',
#  'app wide variety music flaw app amount ad music podcast listen skip hour good app',
#  'best music app good quality song sometimes give interruption hundred thousand song high quality really recommend download',
#  'sooooo annoy week music keep stop second second get pay come spotify try lot trouble shoot logged device change password restart device check account setting update new version reinstall app strong internet connection clear cache else need help please really like app keep go goodbye',
#  'good exact look star give many ad song',
#  'golden standard get premium worth',
#  'great music easy use amazing selection variety',
#  'app forever ad disturb pls take ad anyone money pay premium everyone nowadays pls make demand spotify',
#  'work well part hang occasionally bug',
#  'use app podcasts enjoy however sometimes medium player appear transition different podcast channel rectify relaunch app please see problem',
#  'work little press play button song whole different song play something never hear press show song request play please fix',
#  'thing pick song want play change shuffle play play first song last',
#  'song play complete need give next track manual',
#  'good app listen music',
#  'put song random song always seem one play',
#  'awesome app reduce ad free user',
#  'super awesome android',
#  'extremely poorly optimise autoplays song always unintuitive navigation artist album release',
#  'best aap listen music',
#  'best music stream app android io provide various song choose base person personal recommendation',
#  'amaze app decent amount add',
#  'amaze easy use app good use',
#  'good app good music',
#  'go music keep put music dont know music playlist fix',
#  'use app yet open press app spotify pls fix',
#  'use lite version j instal think lite well button skip close dislike song instead skip undo option u search also crash lot phone literally tell uninstall bc sometines player also dosent work dosent player lite get rid get lite',
#  'always spotify computer get phone great use take long open great',
#  'mean tell order listen song want mobile random song play instead required pay premium yeah star go back youtube',
#  'best app music lover',
#  'brilliant always',
#  'app extremely glitchy think phone poor internet nope reading post see experience others much add premium account thank pretty much still glitchy still premium upgrade desire thanks',
#  'wish cycle song play list playing song herd',
#  'generally good lot music miss thing want suggestion fir kanye suggest appropriate tune',
#  'much use music app allow choose track wan na play do spotify',
#  'use app multiple time daily actually use app spotify amaze extremely large collection music',
#  'see playlist app say need add music podcasts try create new playlist didnt appear library bug please fix',
#  'relationship app dont mind ad fact cant choose song want listen anymore get preview song get skip hour cant anything want almosr song listen premium user put many restriction id rather pay tidal update switch youtube music life much well',
#  'time play playlist press shuffle playlist give random song hear even want hear example play star war playlist nowhere first song go someone drake',
#  'love spotify add free option keep record different type music artist band old new school spotify make daily mix check love get daily horoscope read way work',
#  'week get problem open app black screen spotify logo middle please fix soon possible really enjoy app',
#  'select song get something else ask rhcp get limp bizkit deal dozens ad itd nice get music actually choose',
#  'spotify platform great app android slow glitch fill garbage',
#  'love selection many choose',
#  'thank bring back young girl look old music',
#  'love spotify play great music',
#  'still use ad bro many ad pick play list literally ad go say enjoy next minute ad liying cuz ad pop even minute set ima still use bro ad board',
#  'downgrade star enjoy pay thing work',
#  'love app much use spotify year rarely pose problem issue swiching device listen ir easilly fix suggestion mine woud remote feature app people listen computer hook tv control spotify phone easier',
#  'music podcasts exercise shower cook eat want feel upbeat focus want listen great interview great app',
#  'really good need well sound quality',
#  'best app stream late music hand spotify duo parter create account playlist small price absolutely love spotify highly recommend',
#  'decent service free version get point least much time listen music spent listen ad get want people pay premium truly ridiculous use really like spotify turn played one song literally least lost count ad range second even enjoy next min ad free listen message know next song',
#  'app disconnect internet regularly reason set daughter lullaby ignore guess play song recommendation app cheap expect far good',
#  'best pod cast music',
#  'best option music everything think spotify give recommendation make mix give concert info',
#  'quantity different type music fantastic quality poor time',
#  'impressed many request play selection feature reinstate actually provide rating perfect',
#  'best music app ever rule person enjoy music enjoy app also extremely accessible',
#  'spotify great love idea follow great music podcasts',
#  'really app act lately',
#  'app show playlist want listen podcast app say nothing continually loud hour never end note happen month',
#  'best music app crash way often bug play delay even brand new device ram please try optimize',
#  'trouble consider challenge navigate help site otherwise enjoy',
#  'many ad say ad free min ad continue song',
#  'best app love app really nice app seriously love',
#  'best music selection easy use',
#  'apple music bad well',
#  'love music fingertip spotify decides add music playlist know turn feature sometimes get want recommend music add playlist mess vibe great app thank',
#  'many amazing song hard pick thanks spotify pick pick spotify find give',
#  'best experience app time go play playlist anymore',
#  'use app podcasts mostly keep stop part pause rewind even come pause close app work good app',
#  'many song small handful find certain version sometimes song take sukc cause song still climb love',
#  'app work really well hope change romanise lyric tamil original romanised lyric tamil alot spell mistake hope change original',
#  'add never stay way instead chase sponsor money stick bc lose user r add unnecessary premium ridiculous r u gon tell many song skip playlist unthinkable annoy u rewind song restart simply even control ur playlist point definitely upgrade app make user friendly',
#  'rn unable pause skip play music spotify playlist usually bar allows play skip next song minimize spotify app music play background anymore play song playlist song playlist play reason want pause song play close app entirely problem use never problem',
#  'listen couple short ad get listen arguably great live album ever allman brother live fillmore east get good',
#  'please put option exit playlist listen music extremely frustrating pause music drain battery let app continue run use',
#  'app crash play information ai break fix late update garbage',
#  'good free music easy use',
#  'love premium way expensive consider sirius premium sirius absolutely worth',
#  'excellent playlist select turn jazz',
#  'great app easy use everything listen',
#  'bug awhile amazing',
#  'good app song',
#  'far good build playlist let know',
#  'amaze app leave music streaming guy',
#  'lot song option love playlist put together',
#  'really like sound hello everyone nice day stay safe always god bless',
#  'great many commercial',
#  'tell truth guy prefer spotify station easier customize playlist base individual artist hope plan bring back something close way suggestion choose color playlists hope want see brought back enough people use app guy get ta get ta get thanx listening',
#  'none music actually play ad never music',
#  'good app access load load music ad annoy ad option pay premium overall love app',
#  'great love content get start app act app close listening music podcasts',
#  'spotify fine never pay remove ad mind reason get star removal preview feature something make pointless use playlist app',
#  'love music play favorite song wish play music choose',
#  'best music software yet',
#  'awesome amazing',
#  'love song artist app',
#  'spotify definitely improve lot start use couple year ago almost song look continue add great new feature improvement app sometimes little buggy galaxy otherwise give star',
#  'great app great access music wish listen song wifi get premium',
#  'never know app till friend introduce choose want thanks friend spotify best thing ever happen',
#  'excellent music variety',
#  'good get song even remixes',
#  'love app uninstall reinstall everytime open app stay logo try time work',
#  'main problem absence belarusian language great use app lang',
#  'far good hard control car system sure tweekled perfect',
#  'brilliant love great selection artist fact get day abroad nice recently go spain chill listen favourite song relax thank spotify',
#  'spotify best way listen music mobile tablet search track artist album listen free make share playlists build big best ever music collection get inspire personal recommendation readym',
#  'update shuffle bust play recently discover spinned lot rule counter intuitive people expect shuffle',
#  'experience spotify great thank spotify everyday',
#  'wonderful music play automobile bluetooth fantastic',
#  'app short really lot wait music want recommend thankyou di',
#  'hat iheartradio try improvement iheart far however thing streamline good feature great especially send downloaded podcasts playlist ability reorder playlist library option overall touch screen prefer get want update new update reduce app hot garbage',
#  'nice app free trial quality really go search song give random person playlist skip song nice app premium version',
#  'n ljknmhn mean computer language nbhgcfxdzsbgh sndjkmrtg dfnmb nundfs yep l love',
#  'great actually work issue least time',
#  'actually bad upcoming artiste download bro awesome take lil tentacion rich',
#  'actually good ad enjoy ad',
#  'search specific song press play app play completely different song',
#  'def best music apps support artist song play premium apex ever really helpful able play song pick free user leave download premium also community tab mobile pls',
#  'easy use never problem',
#  'hi spotify listen favorite song get poor play back quality song freeze right middle song song time listen app tried un instal app opening difference need continue spotify premium hopefully get fix come back enjoy song',
#  'bug work pair come app knowing play sound content listen app make kink small price pay',
#  'please fix broken app time samsung galaxy update spotify app break access control audio playing play control cost app',
#  'good algorithm shame app pay good quality',
#  'app need major improvement major issue select medium show currently play unable pause happen question pay premium price application work properly',
#  'play menu go make impossible pause resume song podcast force closing restart app oxygenos',
#  'great app issue try log app load idk phone app',
#  'bar currently play music doesnt come make unable music',
#  'get logged account still premium know email use get charge get spotify premium month something still kindve annoy still free premium card',
#  'love song',
#  'usually work fine keep close soon open try reinstall restart phone open',
#  'good much ad',
#  'absolutely love spotify app ability make awesome playlist add song play station playlist also love spotify creates playlist base music listen heart app definetlely huge variety different song type listen free thing really dislike app able search specifc song',
#  'offline mode available normal version spotify save artist play song',
#  'find music want listen new music also',
#  'great app reduce ad',
#  'great slow phone',
#  'thee best music platform',
#  'use love app become unusable late android',
#  'great music stream service use never problem straightforward user friendly',
#  'spotify best music app doubt request spotify please see give song lyric english hear many song many different indian language always read language tamil telugu read english marathi hindi indian language please see problem otherwise app best',
#  'nice adio quality shoul try provide good quality free',
#  'reason widget home screen quit work long allows skip play lock screen',
#  'far good experience decide become paid member long comutes make app love make personal play list song want',
#  'best app music listening',
#  'amaze app love sometimes able find song cover great u look',
#  'always great song fair price',
#  'best music provider',
#  'app almost year free version pay version music range quality easy use top reason stay spotify',
#  'spotify best',
#  'already subscribe spotify premium still work open device already email hard time open app please fix spotify',
#  'easy app keep make new playlist enjoy alot',
#  'complete garbage team buggy nonfunctional app ever use free version worth give money cash instead develop',
#  'app perfect download fun somedays use shuffle song play random song want play song want great problem start get try redownload still issue even want give problem nothing else',
#  'awesome music awesome app',
#  'love listen music podcasts',
#  'app easy use selection song fit taste music recommend anyone look song choice',
#  'come music really love use application much good',
#  'provide best music quality app essential good music experience million song podcasts enjoy listen music spotify',
#  'enjoy listen favourite old song',
#  'know wrong app fine till update phone software listen laptop think trouble account app rely spotify listen music hope still use phone use app time',
#  'love spotify app',
#  'go amazon music complete trash wish purchase compare',
#  'personalize listening experience love collaborative playlist',
#  'edit reading review wonder company sell venture capitalist everyone mad u guy sorry usually edit excellent rating give app last day really bad right see currently play song queued song make difficult use app kindly correct happy return previous excellent rating thanks simply awesome',
#  'horrible push towards pay premium nothing continuous ad song play limited minute free play let use free skip make phone skip song touch july make previously privated playlist public delete old playlist matter often press button constantly exit app awful',
#  'computer version much well repeat option phone app work pick song wan hear instead random app',
#  'face issue wifi data everything work still show offline everytime tried troubleshoot nothing happens',
#  'love great selection extensive library find lot favorite',
#  'much reliable amazon prime music far big choice music',
#  'much good music app good performance favourite song sigma',
#  'ad disturb overall experience nice',
#  'dude love cant listen music phone lock please fix ill change rating',
#  'excellent app find almost anything',
#  'build list music love explore new music limit best music buy year',
#  'daughter love spotify use apps',
#  'really like app find music heard decades man listen hour thanks damn good app',
#  'play bat keep disappear change song sometimes even play song select multiple time constantly freeze even pause headphone happen completely close app restart start work',
#  'sit add straight free user play completely different song clicked',
#  'recently start randomly stop playing music podcasts go back app press play',
#  'time want listen fave song listen song change totally song',
#  'great look forward new drama great news',
#  'find intresting easy use urge improve use lyric full screen switch app song change switch back lyric screen turn error keep show prev lyric',
#  'function music great app',
#  'best music stream app ever',
#  'great app brilliant music best',
#  'nice app interesting try',
#  'new spotify really',
#  'music apps offline feature allow download certain music free otherwise',
#  'spc yes family car roblox touch see look see question free time get new phone touch let get hold sky good',
#  'work great actually help find new artist',
#  'love spotify anytjing want liaten genre want want podcast',
#  'app amaze new update quite annoy try play playlist always go recommended song skip',
#  'love app feel never improve sometimes glitch refuse play exist enter try listen time friend delay hear song even day bring listen activity tab open want many thing add shame',
#  'good app genre era music give star issue always room unknown improvement',
#  'omg fav app ever really good',
#  'clearly amazing app qith best quality thing dont pike dont offer song mist app situation maybe bad please go ditch ur pandora join spotify ia worth',
#  'favorite app music',
#  'use year never problem pretty good library',
#  'really love listen music love',
#  'enjoy music spotify',
#  'touch hand work change song annoy app',
#  'fantastic app old newsing singing',
#  'love music thank much sharing great job',
#  'excellent music app',
#  'work feel rough clitchy unbelievable big brand spotify make app thats well intrgrated premium android device aaa title use constantly issue simple stuff pause music control app galaxybuds often freeze music stay play background way turn hard closing app andoidauto experience even bad',
#  'thanks dump downloads even tell appreciate also love cellular reception let play podcasts already download also love time go glitchy unreliable app becomes thanks let spotify',
#  'lot good music lot add',
#  'continually riddled issue currently quit play seem spotify truly care customer experience continually felt ignored issue generally leave unresolved excessive amount time awesome know device upgrade ultra issue still like song filter complained month',
#  'music option great podcasts great functionally work half time play song bug cause app show play button reappear restart phone force close app stop playing anything skip song really app break bug',
#  'well satellite radio station offer customize music premium subscription advertising great',
#  'app great read definitely need download',
#  'prefer free coz always drive crazy choose e wallet payment methode gopay telkomsel',
#  'give star reason spotify intentionally screws desktop user deny important feature app block artist desktop force use app use anyway make kinda butt',
#  'pay money month garbage love spotify year get right seriously end subscription switch',
#  'mony app install app wink best gana best',
#  'free trial great thats add x',
#  'wow many song dj rock romantic wow super app',
#  'use music year day ago buy spotify premium edition see good honest spotify well playlist well app find new song youtube music part mix song change week think good spotify honest youtube music well design app spend money music application youtube music free edition well',
#  'everything fine spotify shuffle option often repeat track please improve shuffle option',
#  'app best music app ever see cover sure thing blackpink clarity jisoo pls update app everything awesome',
#  'use best app music',
#  'crash android everytime go full screen think mature app quality control',
#  'easy safe play favorite tune able hear save everything request listen',
#  'love use spotify listen everything amazing fault',
#  'spotify continue surprise depth music available always uplifts day',
#  'user friendly make good suggestion',
#  'highly recommend mostly song available wish sort thing request song want overall actually way well music stream app ever use ad misconception ad never much back back come occasionally guess pretty tolerable anyone use premium keep good job',
#  'easy use able find music enjoy',
#  'good application listen music podcast',
#  'fun app lot diversity option',
#  'good service laptop desktops new update totally ruin experience mobile user make horrible use kebab menu dot icon whenever search song allow add playlist directly play song add playlist dot disappear also mobile user option rearrange song playlist please resolve issue asap',
#  'compare ganna spotify best really love best app',
#  'cut ad good',
#  'suggestion accord mood amazing',
#  'work first bit started play try unstalling installing still work really enjoy app play stop use',
#  'best stream online music app',
#  'give different song instead playing want',
#  'love app absolute best music stream service allows create playlist make accord taste oldie many genre music let get close artist hidden fee agenda absolutely commercial make extremely happy stream favorite artist tour concert able see listen live',
#  'love spotify best',
#  'good app music ad annoy buy premium membership request give download option free user',
#  'really superb app give star advertisement single kindly avoid',
#  'always play song ad know',
#  'awesome experience spotify',
#  'add ability well control volume play alexa speaker group multiple echos device stop pay joe rogans misinformation',
#  'good play song even switch song',
#  'love app always however nothing issue recently play info show pause skip music also stop randomly close app go back press play start playlist continue play bar',
#  'update horrible play music want put random song please remove update make people listen music peace',
#  'excellent app music lover',
#  'overall app pretty good bit confuse phone rather laptop also phone choose song want play playlist get hear snippet song please change come big disadvantage people wish purchase premium',
#  'hi uninstall app handphone check play store also spotify app account still pay subscription fee able assist please thank',
#  'best music app far premium customer',
#  'update spotify load stick logo hope immediate response regard issue thank',
#  'love spotify use app everyday',
#  'absolutely excellent love j acception',
#  'love guy build excellent app move music new microultrasoundlowfreq wave next tesla proudly sponsor congrats',
#  'good superb excellent music app',
#  'listen song offline need premium good',
#  'spotify music app useful attract people make relation happy',
#  'easy use pandora sure skip limit big',
#  'download app time log sign keep tell offline try even strong network connection good',
#  'randomly stop play show control top bar glitchy last year',
#  'awesome love app enjoy playlist',
#  'nice apps expensive get premium',
#  'easy interface glitchy work great old device music dont high bass point bass great app',
#  'love app choice listen favorite',
#  'best streaming app ever tho download spotify play song play song actually dumb make move yt come back go mabey problem still exist others recommend try fix',
#  'best app listen music personally list ad inbetween',
#  'open try many time day ago use search song show network network fine reinstall app opening use work perfect know happen pls an',
#  'cant alot phone try listen favorite wouldnt let u also go back previous song',
#  'hello year young come poor family grow country course money go buy new technology people say anyone relate review probably save allowance couple week go buy vynl record line spotify smartphone beat old vynl afford keep music thanks',
#  'thank goodness spotify',
#  'excellent condition good apps',
#  'cant open spotify show logo click app almost week hope get fix',
#  'app really good sometimes lyric',
#  'amaze app wish go download song fear premium',
#  'really love spotify music',
#  'make playlist mean want listen song put random song spotify give even let skip',
#  'always love spotify pay ad subscription life music suck spotify give joy',
#  'great ui far',
#  'great app surprisingly amazing',
#  'spotify best app ever use felt spotify connect soul heart ever mood spotify play type song love',
#  'really good also premium plan use family plan spotify song like',
#  'spotify awesome',
#  'easy use song artist almost available',
#  'good listening headphone',
#  'please change back old insta story design new bold font design ugly least let choose design want share insta story',
#  'omg new update everything change select individual song album playlist update need well completely vanish',
#  'love app wish playback speed youtube good song ha e sound lot well certain speed get fix next update please thank',
#  'love option rename playlists android mobile',
#  'amaze hack thats life guess',
#  'player stop work app play podcast stop please fix asap',
#  'best music library stream app ever please break broken lyric work lyric incomplete wrong',
#  'great app listen deftones sure problem occur reason keep play random song try play playlist top first song play song never add liked song never play spotify problem fix please mean please fix',
#  'well love trouble contact guy st time good last time wonder folk talk even clue tell twice manually download whole list threaten terminate decide try time able get song back help tech support still fence leave',
#  'best app music',
#  'know app open spotify randomly stop make go app get music back song even almost do restarts spotify great listen music podcasts',
#  'love hear music want interruption thank',
#  'solid experience use app much appreciate',
#  'go knee problem important thing thinking day tomorrow great time effort knee problem important thing thinking day tomorrow great time effort knee problem important thing',
#  'nice relax app keep improve time',
#  'excellent app enjoyable',
#  'ui super intuitive premium feature cool great overall thing keep give star really pay artist well',
#  'enjoy good music serious nice song',
#  'good premium lot ad listen song want',
#  'great app listener',
#  'highly refresh entertainment top notch tune max',
#  'best app listen music ever see',
#  'enjoy podcasts',
#  'play song even like song playlist litter songs genre even listen good luck listen something metal get force listen love song lonely people',
#  'spotify best',
#  'love app even premium still get great music option awesome experience recommend',
#  'really enjoy spotify make playlist put ear buds get lose music thanks spotify yall rock',
#  'log account open stay load screen wifi isnt even issue bcs spotify lite work good',
#  'great song choice',
#  'well got say change mind first think site suck end due diligence get back account pretty cool get member save save everything download whatnot get good way download sd card song f spotify spotify hit download go guys rock',
#  'even premium pick song pretty good',
#  'really enjoy use suggestion love able create playlist folder mobile make much easy look library still wonderful use',
#  'l cancel subscription give runaround cancel debit card',
#  'love music add keep get rid song favorite make happy especially lofi',
#  'wonderful music app love new music spotify find thank',
#  'spotify use app tell play list play list nothing use spotify website play list play list',
#  'overall great application listen music however app bug sooo uhhh yeah even open app anymore stick logo sooo guy lose point recommend',
#  'love xbox mobile app poorly format impossible use limit skip hour b run change song manually view song playlist list individual xbox littoral console controller way control right xbox version well format mobile peice junk',
#  'best music stream service ever',
#  'love best music app thanks',
#  'spotify good music app many add really recommend friend',
#  'best app listen advertisement',
#  'great experience see progression music flourish provide lot musicians keep good work fight artist right best interest',
#  'podcasts use listen audio book tube think keep listening spotify',
#  'get bad song play see player stop skip anything please fix',
#  'get listen favorite band amaze love awesome fan band yeah',
#  'work good pc phone garbage click play song automatically shuffle song click way take shuffle uninstall',
#  'good selection good app',
#  'always great quality always work great',
#  'spotify best music apps planet absolutely ad nothing get way spotify music',
#  'use app long time follow change able listen song watch ad x second x second ad song shorter ad',
#  'best music app ever use spend buck month cd best part app find great new music never find spotify platonic course',
#  'great music app premium',
#  'heart button work add song like song',
#  'go choice podcasts music good app',
#  'recent update need urgent bug fix control bar miss music glitch turn phone screen navigate apps sometimes phone start play randomly know guy quick fix restore update last patch love spotify use want pay app',
#  'click song want hear sometimes put song overall favorite song yeah idk lol still recommend lot people',
#  'keep turn music well change music even playlists give star bite harsh like listen music choose otherwise point playlist',
#  'ot good start musically profile use radio wave brainwave frequency mindhacking device lyric different artist nerve wrack',
#  'switch spotify google discontinue play music regret',
#  'seem random stop music also people accept include free spotify aspotify app upgrade stop complaining',
#  'love app however recently glitchy control song control feature go app stop please fix soon',
#  'pretty awesome get listen music stuff premium wan listen ad song',
#  'convenient easy use',
#  'nice innum song add panuga',
#  'great app glitchy time pay premium',
#  'excellent service chromecast device',
#  'great app wish cheap plan bc kid dont make bank want listen music dont really fund give dollar month know sound lot think get anything enjoy music guess use default limit app great huge option good quality glitchy great',
#  'far good come streaming service first bill month problem library much good lot podcast choose dont even miss neil young',
#  'previous comment cover start brilliant premium plan ad come fast pay listen ad lose playlist etc cancel subscription',
#  'good app many ad',
#  'spotify perfect name spotty best cant believe many time app play music sometimes doesnt want mix phone support fix problem joke pay service way long doesnt work ive look forum nothing fix problem',
#  'best app listen music unfortunately rarest song artist look forward listen sometime available',
#  'still buggy functional still see bug really confuse frustrate alright shuffle work properly improve rating bug fix shuffle improvement',
#  'spoke customer service hour issue final conclusion issue phone model issue specific device clearly market go fix',
#  'best music app',
#  'damn profile picture spotify click man love playlist thank much',
#  'excellent guess kind music hear next always great listen experience',
#  'song heard however big issue enter app say nothing playing much something play play background control notification bar',
#  'awesome app stay date late rap hip hop favorite app music far',
#  'show current song playing leave scour web base lyric much fun',
#  'wish buy membership listen song',
#  'good wish less pay',
#  'overall great improvement couple year audio quality great app synchronise device perfectly love feature switch device play song thing find weak song suggestion use app couple year still recommend make auto playlist groove please start use good ai suggest make good playlist different user',
#  'yes good cause jazz wt heart',
#  'well totally discontinue usage service hope layoff good staff high school intern',
#  'great choice music easy create playlist music always fingertip',
#  'thoroughly enjoy spotify flexibility stream service create playlist favorite type music',
#  'spotify music player good app',
#  'long time user spotify love amount quality music use recently pay nothing everytime try load download song close app couple time load pay ability listen get',
#  'pay premium lately aggressive pausing music im wifi data happen alot people ive talk well please fix',
#  'spotify play favorite song',
#  'app payment issue nepal download lyric please consider minor thing spotify great app listen music',
#  'enjoy listen music spotify kind dumb listen song get ad interruption durning song wise rate give rating better',
#  'improve feature u right swipe playlist get queue well song',
#  'love versatile option explore enjoy music choice',
#  'many great song choose',
#  'use day time subscription worth',
#  'app hard navigate phone click song like go song never heard play demo song dumb play song',
#  'great experience highly recommend',
#  'great app find favorite music',
#  'use beat turn apple music find spotify regret get',
#  'galaxy app unreliable best podcasts drop app crash stop track spotify remember podcast usable',
#  'excellent choice music base taste',
#  'generally good spotify great service remove star team seem generally unwilling listen feedback user community go look help forums ton example issue report backed hundred user indication work please fix shuffle algorithm hour playlist end hearing song day',
#  'love spotify app especially lyrics feature sing',
#  'love great work tool also',
#  'definitely good app music podcast premium subscription thing probably bit overpriced',
#  'love listen download music use data',
#  'enjoy song want right',
#  'love especially favorite song play especially huge music head',
#  'ui need work mean simple feature add swipe mini player end song far good tho',
#  'love download week force buy premium version even play single song buy really annoy love app keep want use',
#  'ok app long use pandora music playing guess try day',
#  'best stream music podcast app especially discover new music app',
#  'good internet connection system keep say im connect whats wrong problem everytime need buy premium please fix',
#  'best music app listen favorites song',
#  'everything work sound great',
#  'good stuff spotify',
#  'ok deal spotify new update add recommend song problem come spotify yo listen playlist music playlist song know sing along way get rid add least song playlist ok everything good spotify keep play song add useless',
#  'app good pls make update delete recent play pls plss beg',
#  'love app try listen fav song put something else give star make ok please',
#  'love spotify recemend friend absolutely love blend play list',
#  'wish good sound quality light mode option',
#  'pay spotify premium ad amazon music absolutely atrocious come podcasts issue spotify anytime anything',
#  'easy use enyable entertainable',
#  'favourite app perfect love spotify',
#  'huge collection music',
#  'amaze music glitchy extremely unreliable podcasts please fix asap premium feel premium anymore edit year later issue remain star becomes star',
#  'interest great format real lovely',
#  'probably personal experience reinstall app time restart phone clear cache twice app work open show logo even give option sign',
#  'ever time try listen certain song always play something different',
#  'good selection music',
#  'wonderful song apps',
#  'spotify introduced much great music base already listen music lover app',
#  'awesome easy',
#  'love useful worth u try',
#  'best music app flaw im android plug headphone spotify automatically start play goig app flaw gon play ad min minute great app overall tho',
#  'playlist spotify mobile anything link account laptop etc work fine mobile star',
#  'play bar disappear skip play episode way come back force close',
#  'love use podcast',
#  'spotify premium great app play fav music',
#  'fantastic app bc cool easy use',
#  'well worth infinity song especially lame whine canadian neil young song',
#  'word app brilliant app',
#  'love app however bug player show become really annoy',
#  'music keep stop reason web player computer way well app',
#  'best music player world love spotify',
#  'wowwwwwww best audio play music platform love awesome',
#  'move deezer constant skipping track restart random shut large stream company mean provide substandard app pay customer advise start payment subscription right issue go month subscription cancel move deezer far superior stream service',
#  'give star take absolute favorites planet net subdigitals give everything else',
#  'great app play music search song want play advert play skip multiple different song sometimes enough skips get song want time go yt play bother wait song know finish playing',
#  'amaze app nd song u u r gon find flexible use nd really good quality',
#  'pretty cool much ad lyric song wrong still',
#  'echo feedback premium user app work perfectly fine month podcasts music pause obvious reason button disappear randomly really frustrate',
#  'best app song available also favourite kaira l love spotify thank spotify amaze',
#  'best music app far',
#  'amaze app feel song ever want play glad download',
#  'brilliant music experience',
#  'really understand big music apps planet buggy frequently miss play tab bottom app mean control skip etc miss randomly say internet connection clearly connect internet stream search song play let autoplay similar song afterwards go back listen original song back selecting song',
#  'best platform stream music tbh',
#  'bug allow song play order show playlist please fix',
#  'absolutly love husband list people follow phish dave matthew widespread panic follow trippylist abd tgeres vands',
#  'nice app handy music guy add music soul mate',
#  'good please add option rearrange song playlist wan open pc google chrome',
#  'app load flash spotify symbol customer support fix google music stop year ago love spotify past week app load uninstalled instal time still load spotify need custom service support value money membership provide much',
#  'little pricey enjoy',
#  'work fine time',
#  'nice app music',
#  'best music browser',
#  'great app skip limit time shuffle button anymore automatically click song take different song chose listen playlist piece',
#  'number aap music apps',
#  'great easy find music',
#  'best music app issue bug',
#  'great work crash time try use need restart phone get work',
#  'love soo feel relief music problem add',
#  'fantastic free',
#  'great music application',
#  'best music app ever',
#  'love spotify music listen podcast go bed night help drift sleep',
#  'app great experience far top notch keep spotify',
#  'app good purchase premium',
#  'shuffle song library like song update shuffle song',
#  'love spotify trouble use android update day ago samsung access kind medium album playlist podcasts song disappear still see playlist exist please fix bug',
#  'really nice make playlist show song need search add',
#  'easy navigate app fav tune',
#  'hifi promise end yet still available competitor hire music spacial audio spotify far competition point wait cancel',
#  'hlo sir spotify user sir request premium plan payment method play store request pls open service play store payment pls humble request',
#  'spotify become smoother last review clear app history lot less big fan new button bottom right corner need make new playlist often dedicate spot menu necessary make podcasts button functionally pointless move button use slightly leave overall still great app nitpick constant change ui',
#  'great music easy navigate',
#  'spotify pay subscription year love app ever last update randomly stop show song play well stop next etc way see reboot device please look fix',
# ...
#  'nice app listen music half time play suggest song want listen song listen want listen playlist song',
#  'never get play playlist try click play music close want try hard mobile app suck please fix super annoy never download app ever recommend',
#  'star work glitchy follow late widget work randomly stop play control bar stop pause play exit app entirely sometimes available car sometimes',
#  'love wish ad long lazy buy something remove bad',
#  'please add item set',
#  'work perfectly start pay app work perfectly year decide try free trail control bar disappear played podcasts come unplayed lose podcasts subscribe renew subscription premium even work',
#  'app suck non functional monthly payment pay money something always functional bug free',
#  'really enjoy free trial get son uograde account premium family account',
#  'please add ability play whole playlist shuffle different song add ability play whole playlist alexa device alex skill please thank much',
#  'love different station ease use find artists song',
#  'love old rock favorite frank marino pat travers well grunge',
#  'nice literally north korea',
#  'good app let unhide song reason',
#  'good app lissent music somethimes understand',
#  'easy use nice premium pay general optional',
#  'spotify year please look pandora',
#  'minute ad tho',
#  'nicee someone hack account time play stranger love know rule know commitment thinkin wouldnt get guy wan tell feeling',
#  'app reflect playlist update let update screen name available support issue remind pay premium',
#  'jre truly reason use spotify pretty good find listen almost anything ad stink especially ad spotify try get pay premium listen ad',
#  'good music app wish student discount apply high schoolers college',
#  'everything good app show tooooo much ad irritate',
#  'stop work recent update even open time time open get blank screen next time open get library uninstalled reinstall twice still get play time open july',
#  'absolutely love app interesting fan light bluetooth pair phone able pick song guest sing dance ceiling fan change color speaker use spotify put many genre fingertips keep party rock',
#  'pay last month premium family wife unfortunately past away week ago love music keep phone family come visit',
#  'problem app use long time like suggest option select song add playlist sometimes bite frustrating choose song individually',
#  'way sort download song artist catch guy year old music player also manage show album art properly whole week straight play bar always show cause also keep controller music car earbuds trash month straight dare ya',
#  'handy car shower music feel cool podcast want discover imagine make',
#  'fine month music player keep disappear pause skip track correctly sometimes cause music stop randomly well really frustrate use samsung',
#  'really nice spotify bring feature use upi subscription premium netflix really help people wan na take subscription card please consider future',
#  'good music app sure spotify premium feature annoy give music functional pandora',
#  'reduces storage fully song make playlist n play online',
#  'love spotify use time bring much joy life',
#  'phenomenal always suggest song prefer perfect quality spotify premium pretty annoy get ad able play song want',
#  'great variety music',
#  'really good use use spotify lot last year issue lose signal car passenger',
#  'keep pause couple second god damn reason scroll top screen press play button mind enter app press play pause',
#  'awesome app many add',
#  'overall good problem ad take long play song want play ad happen listen want listen',
#  'amaze app love music sometimes glitches time u r read review download app go download application',
#  'best place listen music',
#  'good content podcast',
#  'star see update fix issue love app pay year love god unedited song like song switch edit version year old want hear edit version gin juice probably listen r b first place please fix happen many time',
#  'excellent good burning calorie',
#  'spotify year premium user love sound quality music put problem give star keep glitching skip song play keep go song previous skip song great app',
#  'app amaze recent update unable login profile app open get stuck launch show field email address password hope fix bug asap',
#  'app worth keep enjoyed far hope improve sound output',
#  'fun free auto shuffle listen single song even recommend song wait listen song listen song even like',
#  'useful enjoyable app',
#  'spotify great love',
#  'hey give option randomly play song playlist suggestion random song last played song home page app load surprise option netflix',
#  'good music app',
#  'brilliant especially',
#  'best music experience ever',
#  'perfect music app',
#  'usually love spotify recently problem minute play something cut radio silence open app take long time respond show listening end find play begin day whole app open something happened recent update make really buggy laggy',
#  'good music many ad',
#  'great app really strongly recommend',
#  'favorite music',
#  'best app song love really',
#  'issue gapless feature work phone really nice transfer google speaker car work',
#  'song please introduce light theme',
#  'use love play favorite track anytime ad annoy yet bearable however recently able even open app try open spotify kick currently use alternative leave good review next time fix',
#  'share thumbnail appear twice link appear image delete please fix problem asap',
#  'totally unusable last update try troubleshooting day still get nothing frustrate spotify samsung galaxy',
#  'good app people age group excellent senior citizen',
#  'nice app listen sound',
#  'amaze collection old new',
#  'easy use',
#  'many add couls add downlode feture free cool',
#  'great app love proudly recommend ad ok np app help overcome sadness also entertain moment life',
#  'completely different web version good sound quality yet playlist song completely random daily skip get play single song overall app web version way well app',
#  'super cool app get song want tho add still work amazingly well low range',
#  'totaly recommend best music app ever really worth',
#  'love app make feel well se thing happen',
#  'issue app really amazing',
#  'good premium kinda trash',
#  'app run time reopen want resume podcast song der player disappear page load minute app phone work fine',
#  'spotify nice app get playlist load slow',
#  'say great ago equivalent apple music',
#  'nice sort song playlist manuel genre feel app little bit buggy weird sometimes let put song repeat nice app',
#  'good aap aap much type song thanku much aap',
#  'need fix choose music family premium fix please',
#  'good sound quality',
#  'great app spotify best',
#  'best app provide wide range song bgms also support background music well clip song listen clip',
#  'amaze really',
#  'keep wanting use app podcast everytime get discouraged time listen podcast fine pause control see play way stop force stop try point pretty unusable also control translate car connect update issue',
#  'love spotify especially suggest song edit playlist',
#  'let day fix',
#  'open matter tried spent hour try fix pretty good work',
#  'sure improve lot compare earlier day however love see good pricing policy opt avoid add',
#  'find amazing song find ur favourite artist',
#  'pretty good recommendation playlist bury stuff click compose playlist love suggestion make spotify',
#  'search song appear playing song search',
#  'good app listen ad month listen ad issue sometimes play song ruin mood listen ad',
#  'good music',
#  'love spotify',
#  'everything good really app thing canvas available nepal please make sure canvas available nepal',
#  'really love app literally use everyday subscription however reason stop play time play fine min sudden stop play try press play close app completely go back turn back',
#  'wonderful app play music offline even premium problem many ad',
#  'great song app',
#  'love give star undownload wont show song listen',
#  'excellent app love music variety listen app edit last update bad need hear ad get chance hear random song yeah heard right random song let listen want lucky listen song skip shuffle song total star go',
#  'good appp music listener however please stop add kind music playlist good option',
#  'awesome great download track album totally recommend age think use much space recently occasionally crash stop music great app',
#  'love spotify',
#  'love spotify soo much music make sense afford premium u want play song u want worry skip spotify tablet pad u pick song u want play list make sense',
#  'song clarity superb good app hear journal music',
#  'urgent requirement add download music option tha application downloads remain close application free mode',
#  'cool good song ad advisement app excellent',
#  'nice music experience thanku spotify',
#  'cant even listen song last time app suck',
#  'app super awesome get complains happy song lyric think sort far',
#  'spotify really great love sound quality way create playlist crazy listen spotify song amaze',
#  'free version garbage mind ad song free version add song playlist skip play individual song shuffle play skip song hour uninstalled',
#  'great app music',
#  'play meditation music night cut second day drive cut adjust setting full access luck super disappoint',
#  'app nice song collection app show partiality treat language hear hindi song lyric come hindi script however hear tamil song lyric come english script tamil song lyric also come tamil script',
#  'amaze app always calm mood long streeful day',
#  'use great app samsung galaxy user visible player mean pause start stop skip go back track also crash regularly premium user issue year hardly worth subscription useful spotify rectify issue enable user sort listener control update fix issue happen july',
#  'bad app want listen ad thn listen sportify interested song thn plz find app',
#  'good music app',
#  'enjoy spotify use quite gripe list artist mix wish play artist less similar artist',
#  'mostly enjoy app song download recently option shuffle play disappear play song know make playlist thing',
#  'pc spotify version great version need premium song',
#  'rate star play favorite song keep play different song make hate app plss fix',
#  'try play song always show playlist empty go home find playlist resolve issue',
#  'spotify nothing bad',
#  'app perfect give star many song search find spotify soundcloud best song search please add turkish arabic remix lofi miss spotify please fix add thanks',
#  'ad skip bollock chance hearing song request already gamble request sepultura slayer',
#  'app crash time ad play crash switch app comeback spotify app crash always restart app',
#  'single song play add n r heavily annoy even update realize annoy keep thing remove feature ad free video add good see option',
#  'skip want mess sound keep play pause want bug please fix',
#  'play song want skip',
#  'love bts song sooo much thank provide',
#  'half song miss see pay service amazon music well collection music',
#  'song available bts song thing ok please sort thing bts song available',
#  'work great sometimes issue quality audio',
#  'excellent app easy use lot option enjoy music much',
#  'great listen music',
#  'best music app ever use',
#  'get bad meant free get minute advert still get advert listen music minute minute get advert',
#  'love spotify listen podcast ton music song save premium account recommend spotify anyone',
#  'app great however recently l search song play totally different song l choose',
#  'good music listing app',
#  'aap cool find song',
#  'apps really good end exit play song get back song show bottom wish pin playlist library still love spotify',
#  'best app ever create world star doubt u doubt go duck thanks',
#  'idk guy interface feel less control',
#  'rare find song look happens often even obscure music available love lyric offer song never spotify',
#  'app major link playback issue use android firstly play direct song share social medium press green play button bottom right song title app simply ignore play want random artist enter savedplaylist thing happens bias copyright playback specific artist spotify get music play share fix',
#  'really love spotify work please fix',
#  'wrapped year spotify also give count number ad give year many ad good listening music',
#  'exilent sound full hd ad problem love spotify friend download app doubt opinion sarojsk',
#  'best music platform admit especially user subscribes certain problem happy refresh show recently release hit see apps download spotify follow artist still give complete rating update lately good satisfactory hear artist drop track see quickly home page please work acknowledge',
#  'auto artist album list song song artist album generate auto list',
#  'happy app hold artist gap buy phone discover constantly stutter audio playback app long discussion thread spotify community go back april multitude user never find solution resort competition company clearly care also consider',
#  'nice music app play song playlist play suggest song find annoy want listen song add playlist suggest song',
#  'give star song definitely cool good quality advertisement much long use youtube skip sec ad long',
#  'amaze user interface able listen favorite music podcast awesome app',
#  'good till get glitch',
#  'good app streming music',
#  'easy convenient way student stream music app considerably buggy samsung edit bug still persist samsung',
#  'love spotify use day subscription glitchy heck restart middle stuff constantly check stop last night delete reload work',
#  'remove good song stupidify',
#  'love listen app soooooooooo perfect west bengal listen hindi english bengali arabaic song',
#  'app easy use sound great problem keep play suggest song playlist even artist song',
#  'amaze app song best use music many ad everything exceptional premium also good',
#  'nice sound quality',
#  'awesome app music valuable podcasts',
#  'use spotify year work issue load brilliant user submit playlist choose ad often go ad free prefer youtube close screen music podcast playing background music app choice',
#  'cool everyone get premium package everyone use account instead person discount price student music life',
#  'best music app ever see',
#  'love spotify music',
#  'app good know older song song famous song boy visvasam sivaji movie pls add tamil song also recent movie song',
#  'hi spotify devs use spotify late app unresponsive log spotify account app open able login access homepage anything app stay stick screen show spotify logo someone help fix please',
#  'app really good new update ruin app play song want second please fix thanks',
#  'far many ad basic thing free play singular song want listen pay',
#  'addective super play list',
#  'easy way listen music honestly well listen music youtube love',
#  'awesome suck u pay',
#  'use year awesome app use daily use premium long time absolutely regret money well spend',
#  'really ok impacting need available spotify',
#  'spotify also good application internet good offline',
#  'pause play bar go miss please look perhaps something weird last update',
#  'really liked application everyone download problem want listen song internet application still good',
#  'cuberstalers cgberbullies narcissistic hacker bff whole gun kill people people kill people vail hide good thing spinach recall',
#  'love app much problem',
#  'basic feature play thing order unavailable pay',
#  'wonderful keep upbeat need',
#  'get premium life become ease bit thank spotify',
#  'use amazing premium subscriber year late update cause spotify show song play skip stop random interval manually open phone uninstalled reinstall problem still persist',
#  'wish premium otherwise great experience',
#  'great sort miss spotify awesome however life ever vietnam get phished careful',
#  'spotify tha best music thanks',
#  'best app listen favourite music anytime anywhere',
#  'guy add feature song karaoke already lyric song',
#  'auto play random song non sense frustrating set auto play still skip plays random stuff utter garbage good quality song answer random song recommendation',
#  'awesome reference favorite tune',
#  'full entertainment',
#  'good choice hand',
#  ...]

# %%
abc = []
for i in token_str:
    token_list = i.split(" ")
    for i in token_list: 
        abc.append(i)
abc[0:20]
# Out:
# ['great',
#  'music',
#  'service',
#  'audio',
#  'high',
#  'quality',
#  'app',
#  'easy',
#  'use',
#  'also',
#  'quick',
#  'friendly',
#  'support',
#  'please',
#  'ignore',
#  'previous',
#  'negative',
#  'rating',
#  'app',
#  'super']

# %%
b = [r.split(",") for r in abc[0:20]]

# %%
test_id2word = Dictionary(b)
test_corpus = [test_id2word.doc2bow(token) for token in b]

# %%
[[(test_id2word[i], freq) for i,freq in doc] for doc in corpus[:1]]
# Out:
# [[('great', 1),
#   ('music', 1),
#   ('service', 1),
#   ('audio', 1),
#   ('high', 1),
#   ('quality', 1),
#   ('app', 1),
#   ('easy', 1),
#   ('use', 1),
#   ('also', 1),
#   ('quick', 1),
#   ('friendly', 1),
#   ('support', 1)]]

# %%
from gensim.models import LdaModel

# %%
lda_model = LdaModel(corpus=test_corpus,
                    id2word=test_id2word,
                    num_topics=4,
                    random_state=42,
                    chunksize=100,
                    alpha='auto',
                    per_word_topics=True)
vis = pyLDAvis.gensim_models.prepare(lda_model,test_corpus,test_id2word)
vis
# Out:
# C:\Users\Kevin\anaconda3\envs\spotify-proj\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.090779  0.050679       1        1  30.684316
# 3      0.084719  0.058166       2        1  25.005640
# 2      0.002453 -0.056727       3        1  22.155806
# 1      0.003608 -0.052117       4        1  22.154238, topic_info=       Term      Freq     Total Category  logprob  loglift
# 6       app  1.000000  1.000000  Default  19.0000  19.0000
# 3     audio  1.000000  1.000000  Default  18.0000  18.0000
# 10    quick  1.000000  1.000000  Default  17.0000  17.0000
# 7      easy  1.000000  1.000000  Default  16.0000  16.0000
# 9      also  1.000000  1.000000  Default  15.0000  15.0000
# ..      ...       ...       ...      ...      ...      ...
# 17   rating  0.133656  1.024089   Topic4  -3.5011  -0.5291
# 4      high  0.135570  1.042529   Topic4  -3.4869  -0.5328
# 12  support  0.132834  1.024361   Topic4  -3.5072  -0.5356
# 0     great  0.134823  1.042445   Topic4  -3.4924  -0.5382
# 6       app  0.153577  1.536738   Topic4  -3.3621  -0.7961
#
# [95 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 9         4  0.988000      also
# 6         2  0.650729       app
# 3         3  0.988590     audio
# 7         3  0.988389      easy
# 11        1  0.959891  friendly
# 0         1  0.959283     great
# 4         1  0.959206      high
# 14        3  0.988426    ignore
# 1         4  0.987807     music
# 16        4  0.987874  negative
# 13        1  0.959731    please
# 15        2  0.976534  previous
# 5         1  0.959513   quality
# 10        4  0.988024     quick
# 17        2  0.976478    rating
# 2         3  0.988355   service
# 18        1  0.959504     super
# 12        2  0.976218   support
# 8         1  0.959694       use, R=19, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 4, 3, 2])

# %%
#reviews = [i.split(" ") for i in token_str]
#reviews
for i in abc[0:5]:
    reviews = [r.split(",") for r in i]

# %%
abc2 = [i.split(',') for i in abc]

# %%
id2word = Dictionary(b)
corpus = [id2word.doc2bow(review) for review in reviews]

# %%
[[(id2word[i],freq) for i,freq in review] for review in corpus[:1]]
# Out:
# [[('great music service audio high quality app easy use also quick friendly support',
#    1)]]

# %% [markdown]
# ## N-Grams

# %%
bigrams_phrases = gensim.models.Phrases(abc,min_count=3,threshold=20)
bigram = gensim.models.phrases.Phraser(bigrams_phrases)

trigram_phrases = gensim.models.Phrases(abc,min_count=3,threshold=20)
trigam = gensim.models.phrases.Phraser(trigram_phrases)

# %%
def make_bigrams(texts):
    return(bigram[review] for review in texts)

def make_trigrams(texts):
    return(trigam[bigram[review]] for review in texts)

# %%
data_bigrams = make_bigrams(token_str)
data_bigrams_trigrams = make_trigrams(data_bigrams)

# %%
print(data_bigrams_trigrams.)
# Out:
# <generator object make_trigrams.<locals>.<genexpr> at 0x000002DEACFDEC00>
